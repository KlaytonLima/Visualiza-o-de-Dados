# %% [markdown]
# Tratamento de Dados
# * Concatenação
# * Mesclagem
# * Junção de Dados

# %%
# Importação de bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# warnings: Argumento passado para filterwarnings que instrui o Python a ignorar todos os avisos

# %%
# Tratamentos de Dados: Concatenar
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                  index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                  index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                  index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# Concatenação vertical(método concat). Une os registros, um abaixo do outro.
pd.concat([df1, df2, df3], axis=0)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# O método concat() também pode unir dados na horizontal.
# Para isso, os índices dos dataframes devem ser os mesmos eo parâmetro axis=1.
df4 = pd.DataFrame({'E': ['E0', 'E1', 'E2', 'E3'],
                    'F': ['F0', 'F1', 'F2', 'F3'],
                    'G': ['G0', 'G1', 'G2', 'G3'],
                    'H': ['H0', 'H1', 'H2', 'H3']},
                  index=[0, 1, 2, 3])
df4
# Out:
#     E   F   G   H
# 0  E0  F0  G0  H0
# 1  E1  F1  G1  H1
# 2  E2  F2  G2  H2
# 3  E3  F3  G3  H3

# %%
pd.concat([df1, df4], axis=1)
# Out:
#     A   B   C   D   E   F   G   H
# 0  A0  B0  C0  D0  E0  F0  G0  H0
# 1  A1  B1  C1  D1  E1  F1  G1  H1
# 2  A2  B2  C2  D2  E2  F2  G2  H2
# 3  A3  B3  C3  D3  E3  F3  G3  H3

# %%
# Tratamento de Dados: Mesclar
esquerda = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                         'key2': ['K0', 'K1', 'K0', 'K1'],
                         'A': ['A0', 'A1', 'A2', 'A3'],
                         'B': ['B0', 'B1', 'B2', 'B3']})

# %%
direita = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                        'key2': ['K0', 'K0', 'K0', 'K0'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']})

# %%
esquerda.head()
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
direita.head()
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
# Merge(inner)
pd.merge(esquerda, direita, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
# Merge(outer)
pd.merge(esquerda, direita, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %%
# Merge(left)
pd.merge(esquerda, direita, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
# Merge(right)
pd.merge(esquerda, direita, how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %% [markdown]
# Obs: Os parâmetros left_on e right_on devem ser usados quando os nomes dos
# campos chave são direntes entre os dois dataframes

# %%
# Importando CSV
df_regiao = pd.read_csv('noc_region.csv', sep=',')
df_olimpiadas = pd.read_csv('dataset_olympics.csv')
df_olimpiadas.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
df_regiao.head(3)
# Out:
#   noc_region          reg                 notes
# 0        AFG  Afghanistan                   NaN
# 1        AHO      Curacao  Netherlands Antilles
# 2        ALB      Albania                   NaN

# %%
df = pd.merge(df_olimpiadas, df_regiao, how='left', left_on = 'NOC', right_on = 'noc_region')
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#   noc_region    reg notes
# 0        CHN  China   NaN
# 1        CHN  China   NaN

# %%
# Dropando colunas
df.drop(['noc_region'], axis=1, inplace=True, errors='raise')
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal    reg  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN  China
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN  China
#
#   notes
# 0   NaN
# 1   NaN

# %%
# Tratamento de Dados: Juntar
esquerda = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                         'B': ['B0', 'B1', 'B2']},
                       index=['K0', 'K1', 'K2'])
esquerda.head(3)
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
direita = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                        'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])
direita.head(3)
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %% [markdown]
# join(). Retorna todos registros da esquerda e os que
# possuem correspondência de chave da direita:
# No método join, por padrão how=left

# %%
esquerda.join(direita)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
esquerda.join(direita, how='right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
esquerda.join(direita, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
# Tratamento de Dados: Dados Ausentes
# Cria séries de dados
s = {'COL_1': [212, 434, np.nan, 44, np.nan],
     'COL_2': [43, np.nan, np.nan, np.nan, np.nan],
     'COL_3': [555, 603, 102, 770, 809],
     'COL_4': [567, 560, 614, 88, 128],
     'COL_5': [555, 603, 102, 64, np.nan]}

# %%
# Transpôe para Pandas
df = pd.DataFrame(s)
df.head(10)
# Out:
#    COL_1  COL_2  COL_3  COL_4  COL_5
# 0  212.0   43.0    555    567  555.0
# 1  434.0    NaN    603    560  603.0
# 2    NaN    NaN    102    614  102.0
# 3   44.0    NaN    770     88   64.0
# 4    NaN    NaN    809    128    NaN

# %%
# Excluindo linhas
df.dropna(axis=0)
# Out:
#    COL_1  COL_2  COL_3  COL_4  COL_5
# 0  212.0   43.0    555    567  555.0

# %%
# Excluindo colunas
df.dropna(axis=1)
# Out:
#    COL_3  COL_4
# 0    555    567
# 1    603    560
# 2    102    614
# 3    770     88
# 4    809    128

# %%
# Mantendo no dataframe apenas registros que possuem pelo menos 4 valores ausentes
df.dropna(axis=0, thresh=4)
# Out:
#    COL_1  COL_2  COL_3  COL_4  COL_5
# 0  212.0   43.0    555    567  555.0
# 1  434.0    NaN    603    560  603.0
# 3   44.0    NaN    770     88   64.0

# %%
# Substituindo os ausentes por 0
df.fillna(value=0)
# Out:
#    COL_1  COL_2  COL_3  COL_4  COL_5
# 0  212.0   43.0    555    567  555.0
# 1  434.0    0.0    603    560  603.0
# 2    0.0    0.0    102    614  102.0
# 3   44.0    0.0    770     88   64.0
# 4    0.0    0.0    809    128    0.0

# %%
# Substituindo os ausentes ppor uma string
df.fillna(value='Valor ausente')
# Out:
#            COL_1          COL_2  COL_3  COL_4          COL_5
# 0          212.0           43.0    555    567          555.0
# 1          434.0  Valor ausente    603    560          603.0
# 2  Valor ausente  Valor ausente    102    614          102.0
# 3           44.0  Valor ausente    770     88           64.0
# 4  Valor ausente  Valor ausente    809    128  Valor ausente

# %%
# Substituindo os ausentes pelo valor médio da coluna
df['COL_1'] = df['COL_1'].fillna(value = df['COL_1'].mean())
df.head(10)
# Out:
#    COL_1  COL_2  COL_3  COL_4  COL_5
# 0  212.0   43.0    555    567  555.0
# 1  434.0    NaN    603    560  603.0
# 2  230.0    NaN    102    614  102.0
# 3   44.0    NaN    770     88   64.0
# 4  230.0    NaN    809    128    NaN

# %%
# Instalando bibliotecas para visualizar dados ausentes
# !pip install missingno
import missingno as msno
import matplotlib.pyplot as plt

# %%
# Importando os dataframes 
df_regiao = pd.read_csv('noc_region.csv', sep=',')
df_olimpiadas = pd.read_csv('dataset_olympics.csv')

# %%
df_olimpiadas.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %% [markdown]
# Mostrar a quantidade de valores ausentes por coluna
# df.isnull(): Retorna um DataFrame do mesmo tamanha,  com valores True onde os dados estão ausentes (NAN),
# e False onde estão presentes.
# sum(): Quando aplicado a um DataFrame de valores boleanos, ele soma True como 1 e False como 0,
# resultando no número de valores ausentes por coluna.

# %%
missing_values = df_olimpiadas.isnull().sum()
print("Quantidade de valores ausentes por coluna: ")
print(missing_values)
# Out:
# Quantidade de valores ausentes por coluna:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
# Exibe o gráfico de barras para visualizar a quantidade de valores ausentes
msno.bar(df_olimpiadas)
# Out:
# <Axes: >

# %%
# Exibe o gráfico de matriz para observar o padrão dos valores ausentes
msno.matrix(df_olimpiadas)
# Out:
# <Axes: >

# %%
# Tratnado valores ausentes, usando a média dos valores
df = df_olimpiadas
df['Height'] = df['Height'].fillna(value = df['Height'].median())
df['Weight'] = df['Weight'].fillna(value = df['Weight'].median())
df['Age'] = df['Age'].fillna(value = df['Age'].median())
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0   175.0    70.0         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0   175.0    70.0  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Tratamento de Dados: Outliers
# Importando os dataframes 
df_regiao = pd.read_csv('noc_region.csv', sep=',')
df_olimpiadas = pd.read_csv('dataset_olympics.csv')

# %%
df = df_olimpiadas
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
# Adicionando Outliers
# Função para adicionar valores extremos aleatórios (tanto altos quanto baixos) a uma coluna específica.
def add_random_extreme_outliers(df, column, percentage):
    num_outliers = int(len(df) * percentage / 100) # Calcula o número de outliers (10% de dados)
    indices = np.random.choice(df.index, num_outliers, replace=False) # Selecionar linhas aleatoriamente para valores discrepantes.

    # Divida os outliers: a primeira metade para outliers aleatórios grandes, a segunda metade para outliers aleatórios pequenos.
    half = num_outliers // 2

    # Crie grandes outliers aleatórios (valores aleatórios entre 5 e 20 vezes a média da coluna).
    df.loc[indices[:half], column] = df[column].mean() * np.random.uniform(5,20, size=half)

    # Crie pequenos outliers aleatórios (valores aleatórios entre 1/20 e 1/5 da média da coluna).
    df.loc[indices[half:], column] = df[column].mean() * np.random.uniform(0.05, 0.2, size=num_outliers - half)

# Adicione outliers aleatórios a aproximadamente 10% dos dados tanto para 'Altura' quanto para 'Peso'.
add_random_extreme_outliers(df, 'Height', 0.1)
add_random_extreme_outliers(df, 'Weight', 0.1)

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  52908.000000  53755.000000
# mean      71.388766    176.722102
# std       26.462270     55.286779
# min        3.997755      8.843990
# 25%       61.000000    168.000000
# 50%       70.000000    175.000000
# 75%       79.000000    183.000000
# max     1380.363533   3467.584533

# %%
# Tratando outliers
df[['Weight', 'Height']].mean()
# Out:
# Weight     71.388766
# Height    176.722102
# dtype: float64

# %%
# Extremidade superior do peso
df.sort_values(by=['Weight'], ascending=False).head(3)
# Out:
#           ID                    Name Sex   Age  Height       Weight  \
# 12648   6888   Daniel Everton Bailey   M  17.0   179.0  1380.363533
# 41165  21214  Grard Christaud-Pipola   M  36.0   178.0  1370.799502
# 48405  24955      Irene Karine Dalby   F  25.0   181.0  1323.805521
#
#                       Team  NOC        Games  Year  Season      City  \
# 12648  Antigua and Barbuda  ANT  2004 Summer  2004  Summer    Athina
# 41165               France  FRA  1984 Winter  1984  Winter  Sarajevo
# 48405               Norway  NOR  1996 Summer  1996  Summer   Atlanta
#
#            Sport                                  Event Medal
# 12648  Athletics             Athletics Men's 100 metres   NaN
# 41165  Bobsleigh                   Bobsleigh Men's Four   NaN
# 48405   Swimming  Swimming Women's 400 metres Freestyle   NaN

# %%
# Extremidade inferior do peso
df.sort_values(by=['Weight'], ascending=True).head(3)
# Out:
#           ID                         Name Sex   Age  Height    Weight  \
# 69899  35608          Alison Rachel Fitch   F  16.0   176.0  3.997755
# 386      213             Samy Abdel Razek   M  36.0   170.0  4.066938
# 55967  28685  Loredana Dinu (Iordchioiu-)   F  28.0   168.0  4.293712
#
#               Team  NOC        Games  Year  Season            City     Sport  \
# 69899  New Zealand  NZL  1996 Summer  1996  Summer         Atlanta  Swimming
# 386          Egypt  EGY  2016 Summer  2016  Summer  Rio de Janeiro  Shooting
# 55967      Romania  ROU  2012 Summer  2012  Summer          London   Fencing
#
#                                                  Event Medal
# 69899  Swimming Women's 4 x 200 metres Freestyle Relay   NaN
# 386               Shooting Men's Air Pistol, 10 metres   NaN
# 55967                       Fencing Women's epee, Team   NaN

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  52908.000000  53755.000000
# mean      71.388766    176.722102
# std       26.462270     55.286779
# min        3.997755      8.843990
# 25%       61.000000    168.000000
# 50%       70.000000    175.000000
# 75%       79.000000    183.000000
# max     1380.363533   3467.584533

# %%
# Importando os dataframes 
df_regiao = pd.read_csv('noc_region.csv', sep=',')
df_olimpiadas = pd.read_csv('dataset_olympics.csv')

# %%
# Função para adicionar valores extremos aleatórios (tanto altos quanto baixos) a uma coluna específica.
def add_random_extreme_outliers(df, column, percentage):
    num_outliers = int(len(df) * percentage / 100) # Calcula o número de outliers (10% de dados)
    indices = np.random.choice(df.index, num_outliers, replace=False) # Selecionar linhas aleatoriamente para valores discrepantes.

    # Divida os outliers: a primeira metade para outliers aleatórios grandes, a segunda metade para outliers aleatórios pequenos.
    half = num_outliers // 2

    # Crie grandes outliers aleatórios (valores aleatórios entre 5 e 20 vezes a média da coluna).
    df.loc[indices[:half], column] = df[column].mean() * np.random.uniform(5,20, size=half)

    # Crie pequenos outliers aleatórios (valores aleatórios entre 1/20 e 1/5 da média da coluna).
    df.loc[indices[half:], column] = df[column].mean() * np.random.uniform(0.05, 0.2, size=num_outliers - half)

# Adicione outliers aleatórios a aproximadamente 10% dos dados tanto para 'Altura' quanto para 'Peso'.
add_random_extreme_outliers(df, 'Height', 0.1)
add_random_extreme_outliers(df, 'Weight', 0.1)

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  52924.000000  53777.000000
# mean      71.875597    178.048672
# std       34.628732     81.120935
# min        3.997755      8.843990
# 25%       61.000000    168.000000
# 50%       70.000000    175.000000
# 75%       79.000000    183.000000
# max     1389.995011   3516.459606

# %%
# Removendo extremidades dos pesos
df = df[
    (df['Weight'] > df['Weight'].quantile(0.005)) &
    (df['Weight'] < df['Weight'].quantile(0.995))]

# %%
# Removendo extremidades de alturas
df = df[
    (df['Height'] > df['Height'].quantile(0.005)) &
    (df['Height'] < df['Height'].quantile(0.995))]

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  51356.000000  51356.000000
# mean      70.769209    175.635836
# std       13.192778      9.815557
# min       41.000000    151.000000
# 25%       61.000000    169.000000
# 50%       70.000000    175.000000
# 75%       79.000000    183.000000
# max      125.000000    203.000000

# %%
# Dados pós remoções
print("Quantidade de registros", df['Weight'].count())
print("Peso Médio", df['Weight'].mean())
# Out:
# Quantidade de registros 51356
# Peso Médio 70.76920905054911

# %%
# Dados pós remoções
print("Quantidade de registros", df['Height'].count())
print("Altura Média", df['Height'].mean())
# Out:
# Quantidade de registros 51356
# Altura Média 175.63583612430875

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  51356.000000  51356.000000
# mean      70.769209    175.635836
# std       13.192778      9.815557
# min       41.000000    151.000000
# 25%       61.000000    169.000000
# 50%       70.000000    175.000000
# 75%       79.000000    183.000000
# max      125.000000    203.000000

# %%
# Importando os dataframes 
df_regiao = pd.read_csv('noc_region.csv', sep=',')
df_olimpiadas = pd.read_csv('dataset_olympics.csv')
df = df_olimpiadas

# %%
# Função para adicionar valores extremos aleatórios (tanto altos quanto baixos) a uma coluna específica.
def add_random_extreme_outliers(df, column, percentage):
    num_outliers = int(len(df) * percentage / 100) # Calcula o número de outliers (10% de dados)
    indices = np.random.choice(df.index, num_outliers, replace=False) # Selecionar linhas aleatoriamente para valores discrepantes.

    # Divida os outliers: a primeira metade para outliers aleatórios grandes, a segunda metade para outliers aleatórios pequenos.
    half = num_outliers // 2

    # Crie grandes outliers aleatórios (valores aleatórios entre 5 e 20 vezes a média da coluna).
    df.loc[indices[:half], column] = df[column].mean() * np.random.uniform(5,20, size=half)

    # Crie pequenos outliers aleatórios (valores aleatórios entre 1/20 e 1/5 da média da coluna).
    df.loc[indices[half:], column] = df[column].mean() * np.random.uniform(0.05, 0.2, size=num_outliers - half)

# Adicione outliers aleatórios a aproximadamente 10% dos dados tanto para 'Altura' quanto para 'Peso'.
add_random_extreme_outliers(df, 'Height', 0.1)
add_random_extreme_outliers(df, 'Weight', 0.1)

# %%
# Substituindo extremidades superior do peso
df['Weight'] = np.where(df['Weight'] >= df['Weight'].quantile(0.995), 
                        df[(df['Weight'] > df['Weight'].quantile(0.005)) & 
                        (df['Weight'] < df['Weight'].quantile(0.995))]['Weight'].mean(), 
                        df['Weight'])
# Substituindo extremidades superior do peso
df['Weight'] = np.where(df['Weight'] <= df['Weight'].quantile(0.005), 
                       df[(df['Weight'] > df['Weight'].quantile(0.005)) &
                        (df['Weight'] < df['Weight'].quantile(0.995))]['Weight'].mean(),
                        df['Weight'])

# %%
# Substituindo extremidades superior da altura
df['Height'] = np.where(df['Height'] >= df['Height'].quantile(0.995), 
                        df[(df['Height'] > df['Height'].quantile(0.005)) & 
                        (df['Height'] < df['Height'].quantile(0.995))]['Height'].mean(), 
                        df['Height'])
# Substituindo extremidades superior da altura
df['Height'] = np.where(df['Height'] <= df['Height'].quantile(0.005), 
                       df[(df['Height'] > df['Height'].quantile(0.005)) &
                        (df['Height'] < df['Height'].quantile(0.995))]['Height'].mean(),
                        df['Height'])

# %%
df[['Weight', 'Height']].describe()
# Out:
#              Weight        Height
# count  52899.000000  53746.000000
# mean      70.769441    175.512894
# std       13.223235      9.345947
# min       42.000000    153.000000
# 25%       61.000000    169.000000
# 50%       70.000000    175.319319
# 75%       79.000000    182.000000
# max      122.000000    199.000000

# %%
# Dados pós remoções
print("Quantidade de registros", df['Height'].count())
print("Altura Média", df['Height'].mean())
# Out:
# Quantidade de registros 53746
# Altura Média 175.51289391796067

# %%
# Verificar distribuições de pesos e alturas
sns.kdeplot(df['Weight'], legend=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.kdeplot(df['Height'], legend=True)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
# Podem ser criadas funções para discretizar
# Peso
def discrPeso(x):
    if x < df['Weight'].quantile(0.2):
        return 'Muito_Baixo'
    elif x < df['Weight'].quantile(0.4):
        return 'Baixo'
    elif x < df['Weight'].quantile(0.6):
        return 'Médio'
    elif x < df['Weight'].quantile(0.8):
        return 'Alto'
    else:
        return 'Muito_Alto'

# %%
# Altura
def discrAltura(x):
    if x < df['Height'].quantile(0.2):
        return 'Muito_Baixo'
    elif x < df['Height'].quantile(0.4):
        return 'Baixo'
    elif x < df['Height'].quantile(0.6):
        return 'Médio'
    elif x < df['Height'].quantile(0.8):
        return 'Alto'
    else:
        return 'Muito_Alto'

# %%
# Aplicando as funções
df['DESC_WEIGHT'] = df['Weight'].apply(discrPeso)
df['DESC_HEIGHT'] = df['Height'].apply(discrAltura)

# %%
# Criando uma amostra dos dados
df10 = df.sample(frac=0.1, random_state = 123).head()

# %%
df10['DESC_WEIGHT'] = df10['Weight'].apply(discrPeso)
df10['DESC_HEIGHT'] = df10['Height'].apply(discrAltura)

# %%
df10.head(3)
# Out:
#           ID                    Name Sex   Age  Height  Weight       Team  \
# 21971  11582                  Binard   M   NaN     NaN     NaN    Belgium
# 16953   9085         Lucien Beaumont   M  21.0     NaN     NaN     Canada
# 48447  24978  Melvyn "Mel" Dalgleish   M  21.0   198.0    89.0  Australia
#
#        NOC        Games  Year  Season       City       Sport  \
# 21971  BEL  1920 Summer  1920  Summer  Antwerpen     Cycling
# 16953  CAN  1952 Summer  1952  Summer   Helsinki    Swimming
# 48447  AUS  1980 Summer  1980  Summer     Moskva  Basketball
#
#                                      Event Medal DESC_WEIGHT DESC_HEIGHT
# 21971                 Cycling Men's Sprint   NaN  Muito_Alto  Muito_Alto
# 16953  Swimming Men's 100 metres Freestyle   NaN  Muito_Alto  Muito_Alto
# 48447          Basketball Men's Basketball   NaN  Muito_Alto  Muito_Alto

# %%
# Binarizando a coluna 'Gender'
df['Gender_Bin'] = df['Sex'].map({'M':1, 'F': 0})
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal DESC_WEIGHT DESC_HEIGHT  Gender_Bin
# 0   Basketball Men's Basketball   NaN        Alto        Alto           1
# 1  Judo Men's Extra-Lightweight   NaN       Baixo       Baixo           1
# 2       Football Men's Football   NaN  Muito_Alto  Muito_Alto           1

# %%
df['Gender_Bin'] = df['Gender_Bin'].astype(bool)
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal DESC_WEIGHT DESC_HEIGHT  Gender_Bin
# 0   Basketball Men's Basketball   NaN        Alto        Alto        True
# 1  Judo Men's Extra-Lightweight   NaN       Baixo       Baixo        True
# 2       Football Men's Football   NaN  Muito_Alto  Muito_Alto        True

# %%
# Tratamento de Dados: Codificação One-Hot
colunas_discretas = ['Sport'] # Colunas que você quer binarizar

# Binarizando as colunas discretas
df_binarized = pd.get_dummies(df10, columns=colunas_discretas, drop_first=True)
df_binarized.head(3)
# Out:
#           ID                    Name Sex   Age  Height  Weight       Team  \
# 21971  11582                  Binard   M   NaN     NaN     NaN    Belgium
# 16953   9085         Lucien Beaumont   M  21.0     NaN     NaN     Canada
# 48447  24978  Melvyn "Mel" Dalgleish   M  21.0   198.0    89.0  Australia
#
#        NOC        Games  Year  Season       City  \
# 21971  BEL  1920 Summer  1920  Summer  Antwerpen
# 16953  CAN  1952 Summer  1952  Summer   Helsinki
# 48447  AUS  1980 Summer  1980  Summer     Moskva
#
#                                      Event Medal DESC_WEIGHT DESC_HEIGHT  \
# 21971                 Cycling Men's Sprint   NaN  Muito_Alto  Muito_Alto
# 16953  Swimming Men's 100 metres Freestyle   NaN  Muito_Alto  Muito_Alto
# 48447          Basketball Men's Basketball   NaN  Muito_Alto  Muito_Alto
#
#        Sport_Basketball  Sport_Cycling  Sport_Rhythmic Gymnastics  \
# 21971             False           True                      False
# ...

# %%
# A codificação One-Hot transforma variáveis
df_binarized.to_csv('df_binarized.csv', sep=',', index=True, encoding='utf-8')

# %%
df_bin = pd.read_csv('df_binarized.csv')
display(df_bin)
# Out:
#    Unnamed: 0     ID                            Name Sex   Age  Height  \
# 0       21971  11582                          Binard   M   NaN     NaN
# 1       16953   9085                 Lucien Beaumont   M  21.0     NaN
# 2       48447  24978          Melvyn "Mel" Dalgleish   M  21.0   198.0
# 3       42344  21843           Hazel Mae Clark-Riley   F  22.0   178.0
# 4        4376   2492  Nataliya Yuryevna Aleksandrova   F  20.0   171.0
#
#    Weight           Team  NOC        Games  ...  Season       City  \
# 0     NaN        Belgium  BEL  1920 Summer  ...  Summer  Antwerpen
# 1     NaN         Canada  CAN  1952 Summer  ...  Summer   Helsinki
# 2    89.0      Australia  AUS  1980 Summer  ...  Summer     Moskva
# 3    55.0  United States  USA  2000 Summer  ...  Summer     Sydney
# 4    53.0        Belarus  BLR  2004 Summer  ...  Summer     Athina
#
#                                  Event Medal  DESC_WEIGHT DESC_HEIGHT  \
# ...
